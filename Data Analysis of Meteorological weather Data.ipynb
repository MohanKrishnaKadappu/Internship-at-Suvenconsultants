# %% [markdown]
# # Project Phase 1
#
# Performing Analysis of Meteorological data
#
# By Mohan krishna k

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline

# %%
#importing the data as my_data
my_data = pd.read_csv(r'C:\Users\Msi\Documents\data analysis internship\Performing Analysis of Meteorological Data (weather data)\weatherHistory.csv')
#importing csv using pd.read_csv,here r stantds for read to remove unicode error

# %%
my_data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# # I ] Analyze DataFrames

# %%
my_data.head() #head() - shows the first N rows in the data(default n = 5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# ...

# %%
my_data.dtypes #it shows the data-type of each column
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)        int64
# Visibility (km)             float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
my_data.info() #it provides basic information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Pressure (millibars)      96453 non-null  float64
#  10  Daily Summary             96453 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 8.1+ MB

# %%
# as we can clearly see, there is no null values in our dataset but to cross check let's use isnull() method which used to check NULL values in the given data frame.
my_data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# We have too convert the Formatted Date datatype from object to datetype, here we are also telling UTC=True to Pandas that your dates and times should not be naive, but UTC.
my_data['Formatted Date'] = pd.to_datetime(my_data['Formatted Date'],utc=True)

# %%
my_data.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                    int64
# Visibility (km)                         float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %% [markdown]
# These are the data_types after conversion of Formatted Date's datatype which was object to datetime

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Pressure (millibars)      96453 non-null  float64
#  10  Daily Summary             96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(6), int64(1), object(3)
# memory usage: 8.1+ MB

# %%
my_data.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# ...

# %%
my_data['Formatted Date']
# Out:
# 0       2006-03-31 22:00:00+00:00
# 1       2006-03-31 23:00:00+00:00
# 2       2006-04-01 00:00:00+00:00
# 3       2006-04-01 01:00:00+00:00
# 4       2006-04-01 02:00:00+00:00
#                    ...
# 96448   2016-09-09 17:00:00+00:00
# 96449   2016-09-09 18:00:00+00:00
# 96450   2016-09-09 19:00:00+00:00
# 96451   2016-09-09 20:00:00+00:00
# 96452   2016-09-09 21:00:00+00:00
# Name: Formatted Date, Length: 96453, dtype: datetime64[ns, UTC]

# %%
my_data = my_data.set_index('Formatted Date')
my_data.head()
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
# 2006-04-01 00:00:00+00:00                  9.377778      0.89
# 2006-04-01 01:00:00+00:00                  5.944444      0.83
# 2006-04-01 02:00:00+00:00                  6.977778      0.83
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# ...

# %% [markdown]
# Here the given data[Apparent temperature and Humidity] is in hour period, hence we have to resample the given data to monthly for a superior analysis.

# %%
#resample() is a method of pandas dataframes that can be used to summarize data by date or time. The .mean() method will add up all values for each resampling period (ex for each month) to provide a mean[avg] output value for that period.
my_data_monthly_sample = my_data[['Apparent Temperature (C)','Humidity']].resample('M').mean()
my_data_monthly_sample.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-31 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-31 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-28 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-31 00:00:00+00:00                  1.969780  0.778737
# 2006-04-30 00:00:00+00:00                 12.098827  0.728625

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 8), dpi=80, facecolor='lavender', edgecolor='tan')
sns.lineplot(x="Apparent Temperature (C)",y="Humidity",data=my_data_monthly_sample)
plt.title("Relation of Apparent Temperature (C) and Humidity")
# Out:
# Text(0.5, 1.0, 'Relation of Apparent Temperature (C) and Humidity')

# %% [markdown]
# # II ] Plot of Apparent Temperature and Humidity with year

# %%
plt.figure(figsize=(18,8))
plt.plot(my_data_monthly_sample['Humidity'],label='Humidity with year',color='navy')
plt.plot(my_data_monthly_sample['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='magenta')
plt.xlabel("Year",fontsize="16")
plt.title("Plot of Apparent Temperature and Humidity with year")
plt.legend(loc=5,fontsize=11)

# %% [markdown]
# # III ] Now we have to find from month of a month i.e April starting from 2006 to 2016 and for the same period it has been increased or not.

# %%
april = my_data_monthly_sample[my_data_monthly_sample.index.month==4]

# %%
april
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-04-30 00:00:00+00:00                 12.098827  0.728625
# 2007-04-30 00:00:00+00:00                 11.894421  0.536361
# 2008-04-30 00:00:00+00:00                 11.183688  0.693194
# 2009-04-30 00:00:00+00:00                 14.267076  0.567847
# 2010-04-30 00:00:00+00:00                 11.639406  0.706875
# 2011-04-30 00:00:00+00:00                 12.978997  0.591625
# 2012-04-30 00:00:00+00:00                 11.782770  0.650222
# 2013-04-30 00:00:00+00:00                 12.045563  0.677667
# 2014-04-30 00:00:00+00:00                 12.486181  0.691403
# 2015-04-30 00:00:00+00:00                 10.632801  0.547764
# 2016-04-30 00:00:00+00:00                 12.731427  0.659972

# %%
plt.figure(figsize=(12,4))
plt.plot(april['Humidity'],label='Humidity',color='Purple',marker='o')
plt.plot(april['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='pink',marker='o')
plt.xlabel('April Month',fontsize=16,color='Blue')
plt.title("Plot of Apparent Temperature and Humidity with year for April Month")
plt.legend(loc=5,fontsize=10)

# %% [markdown]
# According to the visulization of April month graph for year 2006 to 2016, the average humidity for all period is same. it is neither increasing nor descreasing. But there is huge change in temperature for 2008, 2009 and 2015 year majorly.

# %% [markdown]
# # IV ] This monthly analysis has to be done for all 12 months over the 10 year period. So basically after resampling data from hourly to monthly, then comparing the same month over 10 year period.

# %%
january = my_data_monthly_sample[my_data_monthly_sample.index.month==1]

# %%
february = my_data_monthly_sample[my_data_monthly_sample.index.month==2]

# %%
march = my_data_monthly_sample[my_data_monthly_sample.index.month==3]

# %%
april = my_data_monthly_sample[my_data_monthly_sample.index.month==4]

# %%
may = my_data_monthly_sample[my_data_monthly_sample.index.month==5]

# %%
june = my_data_monthly_sample[my_data_monthly_sample.index.month==6]

# %%
july = my_data_monthly_sample[my_data_monthly_sample.index.month==7]

# %%
august = my_data_monthly_sample[my_data_monthly_sample.index.month==8]

# %%
september = my_data_monthly_sample[my_data_monthly_sample.index.month==9]

# %%
october = my_data_monthly_sample[my_data_monthly_sample.index.month==10]

# %%
november = my_data_monthly_sample[my_data_monthly_sample.index.month==11]

# %%
december = my_data_monthly_sample[my_data_monthly_sample.index.month==12]

# %% [markdown]
# # V ] Plot of Humidity for all year based on its month

# %%
plt.figure(figsize=(18,8))
plt.title("Plot of Humidity for all year based on month")
plt.plot(january['Humidity'],label='January',color='Purple',marker='*')
plt.plot(february['Humidity'],label='Febuary',color='red',marker='*')
plt.plot(march['Humidity'],label='March',color='black',marker='*')
plt.plot(april['Humidity'],label='April',color='yellow',marker='*')
plt.plot(may['Humidity'],label='May',color='blue',marker='*')
plt.plot(june['Humidity'],label='June',color='orange',marker='*')
plt.plot(july['Humidity'],label='July',color='pink',marker='*')
plt.plot(august['Humidity'],label='August',color='green',marker='*')
plt.plot(september['Humidity'],label='September',color='brown',marker='*')
plt.plot(october['Humidity'],label='Octomber',color='violet',marker='*')
plt.plot(november['Humidity'],label='November',color='black',marker='*')
plt.plot(december['Humidity'],label='December',color='silver',marker='*')



plt.legend(loc=0,fontsize=10)

# %% [markdown]
# # VI ] Plot of average Apparent Temperature for all the year based on its month

# %%
plt.figure(figsize=(18,8))
plt.title("Plot of Average apparent temperature for all year based on month")
plt.plot(january['Apparent Temperature (C)'],label='January',color='Purple',marker='*')
plt.plot(february['Apparent Temperature (C)'],label='Febuary',color='red',marker='*')
plt.plot(march['Apparent Temperature (C)'],label='March',color='black',marker='*')
plt.plot(april['Apparent Temperature (C)'],label='April',color='yellow',marker='*')
plt.plot(may['Apparent Temperature (C)'],label='May',color='blue',marker='*')
plt.plot(june['Apparent Temperature (C)'],label='June',color='orange',marker='*')
plt.plot(july['Apparent Temperature (C)'],label='July',color='pink',marker='*')
plt.plot(august['Apparent Temperature (C)'],label='August',color='green',marker='*')
plt.plot(september['Apparent Temperature (C)'],label='September',color='brown',marker='*')
plt.plot(october['Apparent Temperature (C)'],label='Octomber',color='violet',marker='*')
plt.plot(november['Apparent Temperature (C)'],label='November',color='black',marker='*')
plt.plot(december['Apparent Temperature (C)'],label='December',color='silver',marker='*')

plt.legend(loc=0,fontsize=10)

# %% [markdown]
# # VII ] Plot OF Every Month for humidity and temperature [Individually]

# %%
plt.figure(figsize=(18,8))
plt.plot(january['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(january['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('January Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for January Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for January Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(february['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(february['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('February Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for February Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for February Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(march['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(march['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('March Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for March Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for March Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(april['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(april['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('April Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for April Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for April Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(may['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(may['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('May Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for May Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for May Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(june['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(june['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('June Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for June Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for June Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(july['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(july['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('July Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for July Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for July Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(august['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(august['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('August Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for August Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for August Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(september['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(september['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('September Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for September Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for September Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(october['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(october['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('October Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for October Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for October Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(november['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(november['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('November Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for November Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for November Month')

# %%
plt.figure(figsize=(18,8))
plt.plot(december['Humidity'],label='Humidity',color='magenta',marker='*')
plt.plot(december['Apparent Temperature (C)'],label='Apparent Temperature (C)',color='red',marker='o')
plt.xlabel('December Month',fontsize=16,color='Green')
plt.legend(loc=5,fontsize=10)
plt.title("Plot of Apparent Temperature and Humidity with year for December Month")
# Out:
# Text(0.5, 1.0, 'Plot of Apparent Temperature and Humidity with year for December Month')

# %% [markdown]
# # VIII ] Conclusion
#
# According to the January - December graph visualization, April to August Month's temperature change os very frequent[less] Its almost same for all year.But there is no change in humidity for last 10 year[2006 - 2016] for a perticular month. Once more, September to March , there is huge change in temperature but humidity is unchanged.
